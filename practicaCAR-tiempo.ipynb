# %%
# baseline cnn model for mnist
import cv2 as cv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import os
from skimage.io import imread
from matplotlib import cm
from scipy.ndimage import gaussian_filter
from skimage.color import rgb2gray
import math

# %% [markdown]
# # Pequeña

# %%
# %%time
imagen = plt.imread("s.png")
plt.imshow(imagen)

# Lectura de la foto

#Utilizamos el flag 0 para que lea la imagen en escala de grises
data=imread('s.png',cv.IMREAD_GRAYSCALE)

#Comprobamos los valores del array y que no son valores vacios
np.unique(data)

# Algoritmo detección de bordes

# imagen a escala de grises

gray = rgb2gray(imagen)

# 1. Filtro gaussiano

filtro = gaussian_filter(gray,sigma=1)

# 2. Supresion No maxima

# Encuentra el gradiente en la dirección X
grad_x = cv.Sobel(filtro, cv.CV_16SC1, 1, 0)
# Encuentra el gradiente en la dirección y
grad_y = cv.Sobel(filtro, cv.CV_16SC1, 0, 1)
# Convertir el valor del gradiente a 8 bits
x_grad = cv.convertScaleAbs(grad_x)
y_grad = cv.convertScaleAbs(grad_y)
# Combina dos gradientes
combina_grad = cv.addWeighted(x_grad, 0.5, y_grad, 0.5, 0)

# 3. Deteccion de bordes

# paso 4. Algoritmo de doble umbral para detectar y conectar bordes
filas, columnas = combina_grad.shape
imagen_final = np.zeros([filas, columnas])               
# Definir umbral alto y bajo
bajo = 0.2 * np.max(combina_grad)
alto = 0.3 * np.max(combina_grad)
for i in range(1, filas-1):
    for j in range(1, columnas-1):
        if (combina_grad[i, j] < bajo):
            imagen_final[i, j] = 0
        elif (combina_grad[i, j] > alto):
            imagen_final[i, j] = 1
        elif ((combina_grad[i-1, j-1:j+1] < alto).any() or (combina_grad[i+1, j-1:j+1]).any() 
              or (combina_grad[i, [j-1, j+1]] < alto).any()):
            imagen_final[i, j] = 1

cv.imwrite("img_final.png",imagen_final)

# Imagen final

img_final = plt.imread("img_final.png")
plt.imshow(img_final)
# Out:
# CPU times: user 123 ms, sys: 5.21 ms, total: 128 ms
# Wall time: 129 ms
# <timed exec>:16: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.

# %%
# Mediana

# %%
# %%time

imagen = plt.imread("m.png")
plt.imshow(imagen)

# Lectura de la foto

#Utilizamos el flag 0 para que lea la imagen en escala de grises
data=imread('m.png',cv.IMREAD_GRAYSCALE)

#Comprobamos los valores del array y que no son valores vacios
np.unique(data)

# Algoritmo detección de bordes

# imagen a escala de grises

gray = rgb2gray(imagen)

# 1. Filtro gaussiano

filtro = gaussian_filter(gray,sigma=1)

# 2. Supresion No maxima

# Encuentra el gradiente en la dirección X
grad_x = cv.Sobel(filtro, cv.CV_16SC1, 1, 0)
# Encuentra el gradiente en la dirección y
grad_y = cv.Sobel(filtro, cv.CV_16SC1, 0, 1)
# Convertir el valor del gradiente a 8 bits
x_grad = cv.convertScaleAbs(grad_x)
y_grad = cv.convertScaleAbs(grad_y)
# Combina dos gradientes
combina_grad = cv.addWeighted(x_grad, 0.5, y_grad, 0.5, 0)

# 3. Deteccion de bordes

# paso 4. Algoritmo de doble umbral para detectar y conectar bordes
filas, columnas = combina_grad.shape
imagen_final = np.zeros([filas, columnas])               
# Definir umbral alto y bajo
bajo = 0.2 * np.max(combina_grad)
alto = 0.3 * np.max(combina_grad)
for i in range(1, filas-1):
    for j in range(1, columnas-1):
        if (combina_grad[i, j] < bajo):
            imagen_final[i, j] = 0
        elif (combina_grad[i, j] > alto):
            imagen_final[i, j] = 1
        elif ((combina_grad[i-1, j-1:j+1] < alto).any() or (combina_grad[i+1, j-1:j+1]).any() 
              or (combina_grad[i, [j-1, j+1]] < alto).any()):
            imagen_final[i, j] = 1

cv.imwrite("img_final.png",imagen_final)

# Imagen final

img_final = plt.imread("img_final.png")
plt.imshow(img_final)
# Out:
# <timed exec>:16: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
# CPU times: user 1.41 s, sys: 23.4 ms, total: 1.43 s
# Wall time: 1.43 s

# %%
# Grande

# %%
# %%time
imagen = plt.imread("l.png")
plt.imshow(imagen)

# Lectura de la foto

#Utilizamos el flag 0 para que lea la imagen en escala de grises
data=imread('l.png',cv.IMREAD_GRAYSCALE)

#Comprobamos los valores del array y que no son valores vacios
np.unique(data)

# Algoritmo detección de bordes

# imagen a escala de grises

gray = rgb2gray(imagen)

# 1. Filtro gaussiano

filtro = gaussian_filter(gray,sigma=1)

# 2. Supresion No maxima

# Encuentra el gradiente en la dirección X
grad_x = cv.Sobel(filtro, cv.CV_16SC1, 1, 0)
# Encuentra el gradiente en la dirección y
grad_y = cv.Sobel(filtro, cv.CV_16SC1, 0, 1)
# Convertir el valor del gradiente a 8 bits
x_grad = cv.convertScaleAbs(grad_x)
y_grad = cv.convertScaleAbs(grad_y)
# Combina dos gradientes
combina_grad = cv.addWeighted(x_grad, 0.5, y_grad, 0.5, 0)

# 3. Deteccion de bordes

# paso 4. Algoritmo de doble umbral para detectar y conectar bordes
filas, columnas = combina_grad.shape
imagen_final = np.zeros([filas, columnas])               
# Definir umbral alto y bajo
bajo = 0.2 * np.max(combina_grad)
alto = 0.3 * np.max(combina_grad)
for i in range(1, filas-1):
    for j in range(1, columnas-1):
        if (combina_grad[i, j] < bajo):
            imagen_final[i, j] = 0
        elif (combina_grad[i, j] > alto):
            imagen_final[i, j] = 1
        elif ((combina_grad[i-1, j-1:j+1] < alto).any() or (combina_grad[i+1, j-1:j+1]).any() 
              or (combina_grad[i, [j-1, j+1]] < alto).any()):
            imagen_final[i, j] = 1

cv.imwrite("img_final.png",imagen_final)

# Imagen final

img_final = plt.imread("img_final.png")
plt.imshow(img_final)
# Out:
# <timed exec>:16: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
# CPU times: user 1.53 s, sys: 23.5 ms, total: 1.55 s
# Wall time: 1.56 s

# %%
# Muy grande

# %%
# %%time
imagen = plt.imread("xl.jpg")
plt.imshow(imagen)

# Lectura de la foto

#Utilizamos el flag 0 para que lea la imagen en escala de grises
data=imread('xl.jpg',cv.IMREAD_GRAYSCALE)

#Comprobamos los valores del array y que no son valores vacios
np.unique(data)

# Algoritmo detección de bordes

# imagen a escala de grises

gray = rgb2gray(imagen)

# 1. Filtro gaussiano

filtro = gaussian_filter(gray,sigma=1)

# 2. Supresion No maxima

# Encuentra el gradiente en la dirección X
grad_x = cv.Sobel(filtro, cv.CV_16SC1, 1, 0)
# Encuentra el gradiente en la dirección y
grad_y = cv.Sobel(filtro, cv.CV_16SC1, 0, 1)
# Convertir el valor del gradiente a 8 bits
x_grad = cv.convertScaleAbs(grad_x)
y_grad = cv.convertScaleAbs(grad_y)
# Combina dos gradientes
combina_grad = cv.addWeighted(x_grad, 0.5, y_grad, 0.5, 0)

# 3. Deteccion de bordes

# paso 4. Algoritmo de doble umbral para detectar y conectar bordes
filas, columnas = combina_grad.shape
imagen_final = np.zeros([filas, columnas])               
# Definir umbral alto y bajo
bajo = 0.2 * np.max(combina_grad)
alto = 0.3 * np.max(combina_grad)
for i in range(1, filas-1):
    for j in range(1, columnas-1):
        if (combina_grad[i, j] < bajo):
            imagen_final[i, j] = 0
        elif (combina_grad[i, j] > alto):
            imagen_final[i, j] = 1
        elif ((combina_grad[i-1, j-1:j+1] < alto).any() or (combina_grad[i+1, j-1:j+1]).any() 
              or (combina_grad[i, [j-1, j+1]] < alto).any()):
            imagen_final[i, j] = 1

cv.imwrite("img_final.png",imagen_final)

# Imagen final

img_final = plt.imread("img_final.png")
plt.imshow(img_final)
# Out:
# CPU times: user 17.8 s, sys: 310 ms, total: 18.1 s
# Wall time: 18.1 s
